# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../../Cleaned Datasets/KDD-CUPP99/Cleaned_KDDCUPP99.csv")

# %%
df.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  1.074992e+06  1.074992e+06  1.074992e+06  1.074992e+06    1.074992e+06
# mean   1.348908e+02  5.837540e+03  4.873730e+03  2.418623e-05    2.735834e-03
# std    1.321605e+03  2.009617e+06  1.376866e+06  4.917892e-03    8.835986e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 50%    0.000000e+00  2.190000e+02  3.320000e+02  0.000000e+00    0.000000e+00
# 75%    0.000000e+00  3.060000e+02  1.721000e+03  0.000000e+00    0.000000e+00
# max    5.832900e+04  1.379964e+09  1.309937e+09  1.000000e+00    3.000000e+00
#
#              urgent           hot  num_failed_logins     logged_in  \
# count  1.074992e+06  1.074992e+06       1.074992e+06  1.074992e+06
# mean   3.627934e-05  5.427947e-02       1.460476e-04  6.301163e-01
# ...

# %%
features_to_be_normalised = []
feature_list = df.columns
for col in feature_list:
    if (df[col].dtype == 'int64' or df[col].dtype == 'float64') and (df[col].max() - df[col].min() > 1000):
        features_to_be_normalised.append(col)
print(features_to_be_normalised)
# Out:
# ['duration', 'src_bytes', 'dst_bytes', 'num_compromised', 'num_root']

# %%
test_df = df[features_to_be_normalised]
normalized_df= (test_df-test_df.min())/(test_df.max()-test_df.min())

# %%
normalized_df.describe()
# Out:
#            duration     src_bytes     dst_bytes  num_compromised      num_root
# count  1.074992e+06  1.074992e+06  1.074992e+06     1.074992e+06  1.074992e+06
# mean   2.312586e-03  4.230212e-06  3.720582e-06     4.774458e-06  7.867300e-06
# std    2.265777e-02  1.456282e-03  1.051093e-03     1.100695e-03  1.125623e-03
# min    0.000000e+00  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 50%    0.000000e+00  1.586998e-07  2.534472e-07     0.000000e+00  0.000000e+00
# 75%    0.000000e+00  2.217449e-07  1.313803e-06     0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00     1.000000e+00  1.000000e+00
